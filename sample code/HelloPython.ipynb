# %% [markdown]
# Hello Python. This is my very first Python

# %%
print ("Hello World!")
# Out:
# Hello World!

# %%
5+2
# Out:
# 7

# %%
a = 345
b = True
num1 = 5
num2=2.1

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# bool

# %%
type(num1)
# Out:
# int

# %%
type(num2)
# Out:
# float

# %%
myfile = open("test.dat", 'w')
myfile.write(a)
myfile.write("\n")
myfile.write("Hello World!\n")
myfile.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-a23502b18884> in <module>
#       1 myfile = open("test.dat", 'w')
# ----> 2 myfile.write(a)
#       3 myfile.write("\n")
#       4 myfile.write("Hello World!\n")
#       5 myfile.close()
#
# TypeError: write() argument must be str, not int
